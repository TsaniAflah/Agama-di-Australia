# %% [markdown]
# <a href="https://colab.research.google.com/github/TsaniAflah/Agama-di-Australia/blob/main/TUGAS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Tsani Aflah

# %% [markdown]
# Npm : 2008107010015

# %% [markdown]
# Kelas : Prak.Visualisasi Data B

# %% [markdown]
# ---

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
pip install openpyxl

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import plotly.express as px
import plotly.graph_objects as go

# %%
df_can = pd.read_csv('Australian religion 1881 - 2016.csv')

# %% [markdown]
# *NOTE : df_can dapat diganti dengan sebutan lainnya*

# %%
df_can.head()
# Out:
#           Religion     1881     1882  ...      2014      2015    2016
# 0   Uniting Church      NaN      0.0  ...  238790.4  228024.2  217258
# 1     Presbyterian  72545.0  76231.8  ...  197788.6  193060.8  188333
# 2  Other Christian  14739.0  14127.3  ...  155676.4  164029.2  172382
# 3          Baptist   7307.0   7887.5  ...   96735.8   95689.4   94643
# 4      Pentecostal      NaN      0.0  ...   78907.6   79618.8   80330
#
# [5 rows x 137 columns]

# %%
print(df_can.shape)
# Out:
# (34, 137)

# %%
df_can.drop(["1881", "1882", "1883", "1884", "1885", "1886", "1887", "1888", "1889", "1890"], axis=1, inplace=True)

# %%
df_can.head()
# Out:
#           Religion      1891      1892  ...      2014      2015    2016
# 0   Uniting Church       NaN       NaN  ...  238790.4  228024.2  217258
# 1     Presbyterian  109413.0  111734.1  ...  197788.6  193060.8  188333
# 2  Other Christian    8622.0    8841.7  ...  155676.4  164029.2  172382
# 3          Baptist   13112.0   13462.6  ...   96735.8   95689.4   94643
# 4      Pentecostal       NaN       0.7  ...   78907.6   79618.8   80330
#
# [5 rows x 127 columns]

# %%
df_can.rename(columns={'Religion':'Belief'}, inplace=True)

df_can.head()
# Out:
#             Belief      1891      1892  ...      2014      2015    2016
# 0   Uniting Church       NaN       NaN  ...  238790.4  228024.2  217258
# 1     Presbyterian  109413.0  111734.1  ...  197788.6  193060.8  188333
# 2  Other Christian    8622.0    8841.7  ...  155676.4  164029.2  172382
# 3          Baptist   13112.0   13462.6  ...   96735.8   95689.4   94643
# 4      Pentecostal       NaN       0.7  ...   78907.6   79618.8   80330
#
# [5 rows x 127 columns]

# %%
all(isinstance(column, str) for column in df_can.columns)
# Out:
# True

# %%
df_can.set_index('Belief', inplace=True)

df_can.head()
# Out:
#                      1891      1892      1893  ...      2014      2015    2016
# Belief                                         ...
# Uniting Church        NaN       NaN       NaN  ...  238790.4  228024.2  217258
# Presbyterian     109413.0  111734.1  114055.2  ...  197788.6  193060.8  188333
# Other Christian    8622.0    8841.7    9061.4  ...  155676.4  164029.2  172382
# Baptist           13112.0   13462.6   13813.2  ...   96735.8   95689.4   94643
# Pentecostal           NaN       0.7       1.4  ...   78907.6   79618.8   80330
#
# [5 rows x 126 columns]

# %%
df_can.drop(["Uniting Church"], axis=0, inplace=True)

# %%
df_can.head()
# Out:
#                       1891      1892      1893  ...      2014      2015    2016
# Belief                                          ...
# Presbyterian      109413.0  111734.1  114055.2  ...  197788.6  193060.8  188333
# Other Christian     8622.0    8841.7    9061.4  ...  155676.4  164029.2  172382
# Baptist            13112.0   13462.6   13813.2  ...   96735.8   95689.4   94643
# Pentecostal            NaN       0.7       1.4  ...   78907.6   79618.8   80330
# Eastern Orthodox       NaN      56.1     112.2  ...  130687.4  100783.2   70879
#
# [5 rows x 126 columns]

# %%
df_can['Total'] = df_can.sum(axis=1)

df_can.head()
# Out:
#                       1891      1892      1893  ...      2015    2016         Total
# Belief                                          ...
# Presbyterian      109413.0  111734.1  114055.2  ...  193060.8  188333  3.039216e+07
# Other Christian     8622.0    8841.7    9061.4  ...  164029.2  172382  4.989260e+06
# Baptist            13112.0   13462.6   13813.2  ...   95689.4   94643  6.271654e+06
# Pentecostal            NaN       0.7       1.4  ...   79618.8   80330  1.904135e+06
# Eastern Orthodox       NaN      56.1     112.2  ...  100783.2   70879  9.322430e+06
#
# [5 rows x 127 columns]

# %%
print('data dimensions:', df_can.shape)
# Out:
# data dimensions: (33, 127)

# %%
years = list(map(str, range(1891, 2017)))
years
# Out:
# ['1891',
#  '1892',
#  '1893',
#  '1894',
#  '1895',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '1900',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '1910',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '1920',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **F I L T E R I N G**

# %%
condition = df_can['2016'] == '267659'

print(condition)
# Out:
# Belief
# Presbyterian                                   False
# Other Christian                                False
# Baptist                                        False
# Pentecostal                                    False
# Eastern Orthodox                               False
# Jehovah's Whitnesses                           False
# Judaism                                        False
# Other Protestant                               False
# Oriental Orthodox                              False
# Seventh-day Adventist                          False
# Lutheran                                       False
# Latter-day Saints                              False
# Salvation Army                                 False
# Assyrian Apostolic                             False
# Brethren                                       False
# Churches of Christ                             False
# Baha'I                                         False
# Catholic                                       False
# ...

# %%
print('data dimensions:', df_can.shape)
print(df_can.columns)
df_can.head(3)
# Out:
# data dimensions: (33, 127)
# Index(['1891', '1892', '1893', '1894', '1895', '1896', '1897', '1898', '1899',
#        '1900',
#        ...
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        'Total'],
#       dtype='object', length=127)
#                      1891      1892      1893  ...      2015    2016       Total
# Belief                                         ...
# Presbyterian     109413.0  111734.1  114055.2  ...  193060.8  188333  30392159.5
# Other Christian    8622.0    8841.7    9061.4  ...  164029.2  172382   4989260.5
# Baptist           13112.0   13462.6   13813.2  ...   95689.4   94643   6271653.5
#
# [3 rows x 127 columns]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **AREA PLOT**

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')  # optional: for ggplot-like style

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.2.2

# %%
df_can.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top5 = df_can.head()

# transpose the dataframe
df_top5 = df_top5[years].transpose()

df_top5.head()
# Out:
# Belief  Anglican  Catholic  Other Spiritual Belief  No Religion  Presbyterian
# 1891    506862.0  287510.0                 21095.0          NaN      109413.0
# 1892    518822.4  293540.6                 20691.0        164.2      111734.1
# 1893    530782.8  299571.2                 20287.0        328.4      114055.2
# 1894    542743.2  305601.8                 19883.0        492.6      116376.3
# 1895    554703.6  311632.4                 19479.0        656.8      118697.4

# %%
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area',
             stacked=False,
             figsize=(20, 10))  # pass a tuple (x, y) size

plt.title("Australia's 5 most adherent religions")
plt.ylabel('Number of religious adherents')
plt.xlabel('Years')

plt.show()

# %%
df_top5.plot(kind='area', 
             alpha=0.25,  # 0 - 1, default value alpha = 0.5
             stacked=False,
             figsize=(20, 10))

plt.title("Australia's 5 most adherent religions")
plt.ylabel('Number of religious adherents')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# *DUA TIPE DARI PLOTTING*
#
# >Lapisan skrip (metode prosedural)
# -> menggunakan matplotlib.pyplot sebagai 'plt'

# %%
df_top5.plot(kind='area', alpha=0.35, figsize=(20, 10)) 
plt.title("Australia's 5 most adherent religions")
plt.ylabel('Number of religious adherents')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# > Lapisan artist (Metode berorientasi objek)
#  -> menggunakan instance Sumbu dari Matplotlib (lebih disukai)

# %%
ax = df_top5.plot(kind='area', alpha=0.35, figsize=(20, 10))

ax.set_title("Australia's 5 most adherent religions")
ax.set_ylabel('Number of religious adherents')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **HISTOGRAM**

# %%
df_can['2016'].head()
# Out:
# Belief
# Anglican                  1161974
# Catholic                  1974973
# Other Spiritual Belief     696204
# No Religion               1879564
# Presbyterian               188333
# Name: 2016, dtype: int64

# %%
count, bin_edges = np.histogram(df_can['2016'])

print(count) # frequency count
print(bin_edges) # bin ranges, default = 10 bins
# Out:
# [27  2  0  1  0  1  0  0  0  2]
# [5.4200000e+02 1.9798510e+05 3.9542820e+05 5.9287130e+05 7.9031440e+05
#  9.8775750e+05 1.1852006e+06 1.3826437e+06 1.5800868e+06 1.7775299e+06
#  1.9749730e+06]

# %%
df_can['2016'].plot(kind='hist', figsize=(8, 5))

# add a title to the histogram
plt.title('Histogram of adherents from religions from Australia in 2016')
# add y-label
plt.ylabel('Number of Religions')
# add x-label
plt.xlabel('Number of Adherents')

plt.show()

# %%
df_can.loc[['Islam', 'Catholic', 'No Religion'], years]
# Out:
#                  1891      1892      1893  ...       2014       2015     2016
# Belief                                     ...
# Islam           528.0     582.4     636.8  ...   248344.0   257999.0   267654
# Catholic     287510.0  293540.6  299571.2  ...  1945938.6  1960455.8  1974973
# No Religion       NaN     164.2     328.4  ...  1612140.8  1745852.4  1879564
#
# [3 rows x 126 columns]

# %%
# generate histogram
df_can.loc[['Islam', 'Catholic', 'No Religion'], years].plot.hist()

# %% [markdown]
# *NOTE : terlihat belum bagus maka :*

# %%
df_t = df_can.loc[['Islam', 'Catholic', 'No Religion'], years].transpose()

df_t.head()
# Out:
# Belief  Islam  Catholic  No Religion
# 1891    528.0  287510.0          NaN
# 1892    582.4  293540.6        164.2
# 1893    636.8  299571.2        328.4
# 1894    691.2  305601.8        492.6
# 1895    745.6  311632.4        656.8

# %%
df_t.plot(kind='hist', figsize=(10, 6))

plt.title('Histogram of Islam, Catholic, No Religion adherents from 1891 - 2016')
plt.ylabel('Number of years')
plt.xlabel('Number of Adherents')

plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **BAR CHARTS**

# %%
df_islam = df_can.loc['Islam', years]

df_islam.head()
# Out:
# 1891    528.0
# 1892    582.4
# 1893    636.8
# 1894    691.2
# 1895    745.6
# Name: Islam, dtype: float64

# %%
df_islam.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Year')
plt.ylabel('Number of Adherents')
plt.title('Histogram of Islam adherents in Australia from 2014 to 2016')

plt.show()

# %%
df_islam.plot(kind='bar', figsize=(10, 6), rot=90)  # rotate the xticks(labelled points on x-axis) by 90 degrees

plt.xlabel('Year')
plt.ylabel('Number of Adherents')
plt.title('Histogram of Islam adherents in Australia from 2014 to 2016')

# Annotate arrow
plt.annotate('',  # s: str. Will leave it blank for no text
             xy=(32, 70),  # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),  # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',  # will use the coordinate system of the object being annotated
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
             )

plt.show()

# %%
df_islam.plot(kind='bar', figsize=(10, 6), rot=90)

plt.xlabel('Year')
plt.ylabel('Number of Adherents')
plt.title('Histogram of Islam adherents in Australia from 2014 to 2016')

# Annotate arrow
plt.annotate('',  # s: str. will leave it blank for no text
             xy=(100, 150),  # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),  # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',  # will use the coordinate system of the object being annotated
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
             )

# Annotate Text
plt.annotate('religious adherents in australia',  # text to display
             xy=(28, 30),  # start the text at at point (year 2008 , pop 30)
             rotation=72.5,  # based on trial and error to match the arrow
             va='bottom',  # want the text to be vertically 'bottom' aligned
             ha='left',  # want the text to be horizontally 'left' algned.
             )

plt.show()
